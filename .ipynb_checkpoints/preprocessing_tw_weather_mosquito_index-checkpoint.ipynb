# %%
import pandas as pd
import numpy as np

# %%
from tqdm import tqdm

# %%
import collections

# %% [markdown]
# # Pre-processing BI data

# %%
path = './data/MosIndex_All.csv'
data = pd.read_csv(path, low_memory = False)

# %%
data.head()
# Out:
#          Date County Town Village    VillageID        VillageLon  \
# 0  2010/01/01    台北市  中正區     三愛里  6300500-031  121.530593083676
# 1  2010/01/01    嘉義市   西區     保安里  1002002-011  120.431350323348
# 2  2010/01/02    高雄市  鳳山區     生明里  6401200-045   120.36306711902
# 3  2010/01/02    台中市  大里區     塗城里  6602800-016  120.717131600963
# 4  2010/01/03    宜蘭縣  蘇澳鎮     存仁里  1000203-004  121.845912904116
#
#          VillageLat AreaType  HouseHold InspectType  ...  HIAeg  HILv  \
# 0  25.0358286563398       住宅         50         衛生所  ...  0.000     0
# 1  23.4910599871089       住宅        156         衛生局  ...  0.000     0
# 2  22.6176350677023       住宅         60          監測  ...  3.333     1
# 3  24.0852343263972       住宅         50         衛生所  ...  0.000     0
# 4  24.6259386590972       住宅         60         衛生所  ...  0.000     0
#
#    HILvAeg     CI  CILv     LI  LILv  Pupa      AI  Con100HH
# 0        0  0.000     0  0.000     0     0  0.0000      0.00
# 1        0  0.000     0  0.000     0     0  0.0000      0.00
# 2        1  5.714     3  0.000     0     0  0.0333      3.33
# 3        0  0.000     0  0.000     0     0  0.0000      0.00
# 4        0  0.000     0  0.000     0     0  0.0000      0.00
#
# [5 rows x 41 columns]

# %%
county = data['County'].unique().tolist()
len(county)
# Out:
# 22

# %%
county.remove('新竹市')
county.remove('嘉義市')

# %%
print(county)
# Out:
# ['台北市', '高雄市', '台中市', '宜蘭縣', '台南市', '新北市', '彰化縣', '花蓮縣', '金門縣', '雲林縣', '新竹縣', '嘉義縣', '桃園市', '澎湖縣', '南投縣', '屏東縣', '台東縣', '基隆市', '連江縣', '苗栗縣']

# %%
use_cols = ['Date', 'County', 'BI', 'HI', 'CI']
bi_hi_ci = ['Date', 'BI', 'HI', 'CI']

# %%
data_distill = data[use_cols]

# %%
data_distill.head()
# Out:
#          Date County     BI     HI     CI
# 0  2010/01/01    台北市  0.000  0.000  0.000
# 1  2010/01/01    嘉義市  0.000  0.000  0.000
# 2  2010/01/02    高雄市  3.333  3.333  5.714
# 3  2010/01/02    台中市  0.000  0.000  0.000
# 4  2010/01/03    宜蘭縣  0.000  0.000  0.000

# %%
# split data for 20 county

cnty_data = collections.defaultdict(list)

for i in tqdm(range(data_distill.shape[0])):
    row = data_distill.iloc[i, :].tolist()
    cnty = row[1]
    if cnty in county:
        #print(row)
        cnty_data[cnty].append(row)
# Out:
#   0%|          | 0/444878 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#   0%|          | 697/444878 [00:00<01:03, 6964.15it/s]
#
#
#
#
#
#
#
#
#
#   0%|          | 1404/444878 [00:00<01:03, 6991.51it/s]
#
#
#
#
#
#
#
#
#
#   0%|          | 2200/444878 [00:00<01:01, 7255.96it/s]
#
#
#
#
#
#
#
#
#
#   1%|          | 2870/444878 [00:00<01:02, 7078.51it/s]
#
#
#
#
#
#
#
#
#
#   1%|          | 3643/444878 [00:00<01:00, 7261.43it/s]
#
#
#
#
#
#
#
#
#
#   1%|          | 4348/444878 [00:00<01:01, 7194.01it/s]
#
#
#
#
#
#
#
#
#
#   1%|          | 5035/444878 [00:00<01:02, 7093.28it/s]
#
#
#
#
#
#
#
#
#
#   1%|▏         | 5810/444878 [00:00<01:00, 7276.09it/s]
#
#
#
#
#
#
#
#
#
#   1%|▏         | 6548/444878 [00:00<01:00, 7304.97it/s]
#
#
#
#
#
#
#
#
#
#   2%|▏         |
    
    tm['Year'] = pd.to_datetime(tm['Date']).dt.year 

    tmm = tm[tm['Year'] >= 2012]

    tmm = tmm.groupby('Date', as_index=False).agg(['mean'])
    tmm.reset_index(level=tmm.index.names, inplace=True)
    #print(tm.head())

    tm2 = convert_date_to_yyyy_ww(tmm, date_week)
    
    tm3 = groupby_yyyy_ww(tm2)
    
    #print(len(sorted(tm3.Year_Week)))

    tm4 = gen_full_time_table(tm3, week_total, county = k)

    #df.apply(lambda x: x.fillna(x.mean()),axis=0)
    
    # fill NaN
    
    #tm4['BI'] = tm4['BI'].fillna(tm4['BI'].mean())
    #tm4['CI'] = tm4['CI'].fillna(tm4['CI'].mean())
    #tm4['HI'] = tm4['HI'].fillna(tm4['HI'].mean())
    
    # count specific value
    selected_words = ['NaN']
    for c in tm4:
        print('\nk = ', k, tm4.loc[tm4[c].isin(selected_words),c].value_counts())

    data_fin2[k] = tm4
    #data_fin2[k] = tm4.fillna(tm4.mean()) # fill NaN by df.mean()
    #data_fin2[k] = tm4.apply(lambda x: x.fillna(x.mean()),axis=0)
# Out:
#  Count missing weeks of each county!
#
#
# k =  新竹縣 Series([], Name: YYYY_WW, dtype: int64)
#
# k =  新竹縣 NaN    107
# Name: BI, dtype: int64
#
# k =  新竹縣 NaN    107
# Name: CI, dtype: int64
#
# k =  新竹縣 NaN    107
# Name: HI, dtype: int64
#
# k =  新竹縣 Series([], Name: County, dtype: int64)
#
# k =  彰化縣 Series([], Name: YYYY_WW, dtype: int64)
#
# k =  彰化縣 NaN    83
# Name: BI, dtype: int64
#
# k =  彰化縣 NaN    83
# Name: CI, dtype: int64
#
# k =  彰化縣 NaN    83
# Name: HI, dtype: int64
#
# k =  彰化縣 Series([], Name: County, dtype: int64)
#
# k =  屏東縣 Series([], Name: YYYY_WW, dtype: int64)
#
# k =  屏東縣 NaN    32
# Name: BI, dtype: int64
#
# k =  屏東縣 NaN    32
# Name: CI, dtype: int64
#
# k =  屏東縣 NaN    32
# Name: HI, dtype: int64
#
# k =  屏東縣 Series([], Name: County, dtype: int64)
#
# k =  新北市 Series([], Name: YYYY_WW, dtype: int64)
#
# k =  新北市 NaN    24
# Name: BI, dtype: int64
#
# k =  新北市 NaN    24
# Name: CI, dtype: int64
#
# k =  新北市 NaN    24
# Name: HI, dtype: int64
#
# k =  新北市 Series([], Name: County, dtype: int64)
#
# k =  花蓮縣 Series([], Name: YYYY_WW, dtype: int64)
#
# k =  花蓮縣 NaN    45
# Name: BI, dtype: int64
#
# k =  花蓮縣 NaN    45
# Name: CI, dtype: int64
#
# k =  花蓮縣 NaN    45
# Name: HI, dtype: int64
#
# k =  花蓮縣 Series([], Name: County, dtype: int64)
#
# k =  台東縣 Series([], Name: YYYY_WW, dtype: int64)
#
# k =  台東縣 NaN    44
# Name: BI, dtype: int64
#
# k =  台東縣 NaN    44
# Name: CI, dtype: int64
#
# k =  台東縣 NaN    44
# Name: HI, dtype: int64
#
# k =  台東縣 Series([], Name: County, dtype: int64)
#
# k =  雲林縣 Series([], Name: YYYY_WW, dtype: int64)
#
# k =  雲林縣 NaN    100
# Name: BI, dtype: int64
#
# k =  雲林縣 NaN    100
# Name: CI, dtype: int64
#
# k =  雲林縣 NaN    100
# Name: HI, dtype: int64
#
# k =  雲林縣 Series([], Name: County, dtype: int64)
#
# k =  高雄市 Series([], Name: YYYY_WW, dtype: int64)
#
# k =  高雄市 NaN    2
# Name: BI, dtype: int64
#
# k =  高雄市 NaN    2
# Name: CI, dtype: int64
#
# k =  高雄市 NaN    2
# Name: HI, dtype: int64
#
# k =  高雄市 Series([], Name: County, dtype: int64)
#
# k =  桃園市 Series([], Name: YYYY_WW, dtype: int64)
#
# k =  桃園市 NaN    98
# Name: BI, dtype: int64
#
# k =  桃園市 NaN    98
# Name: CI, dtype: int64
#
# k =  桃園市 NaN    98
# Name: HI, dtype: int64
#
# k =  桃園市 Series([], Name: County, dtype: int64)
#
# k =  嘉義縣 Series([], Name: YYYY_WW, dtype: int64)
#
# k =  嘉義縣 NaN    44
# Name: BI, dtype: int64
#
# k =  嘉義縣 NaN    44
# Name: CI, dtype: int64
#
# k =  嘉義縣 NaN    44
# Name: HI, dtype: int64
#
# k =  嘉義縣 Series([], Name: County, dtype: int64)
#
# k =  南投縣 Series([], Name: YYYY_WW, dtype: int64)
#
# k =  南投縣 NaN    97
# Name: BI, dtype: int64
#
# k =  南投縣 NaN    97
# Name: CI, dtype: int64
#
# k =  南投縣 NaN    97
# Name: HI, dtype: int64
#
# k =  南投縣 Series([], Name: County, dtype: int64)
#
# k =  苗栗縣 Series([], Name: YYYY_WW, dtype: int64)
#
# k =  苗栗縣 NaN    154
# Name: BI, dtype: int64
#
# k =  苗栗縣 NaN    154
# Name: CI, dtype: int64
#
# k =  苗栗縣 NaN    154
# Name: HI, dtype: int64
#
# k =  苗栗縣 Series([], Name: County, dtype: int64)
#
# k =  基隆市 Series([], Name: YYYY_WW, dtype: int64)
#
# k =  基隆市 NaN    245
# Name: BI, dtype: int64
#
# k =  基隆市 NaN    245
# Name: CI, dtype: int64
#
# k =  基隆市 NaN    245
# Name: HI, dtype: int64
#
# k =  基隆市 Series([], Name: County, dtype: int64)
#
# k =  台北市 Series([], Name: YYYY_WW, dtype: int64)
#
# k =  台北市 NaN    70
# Name: BI, dtype: int64
#
# k =  台北市 NaN    70
# Name: CI, dtype: int64
#
# k =  台北市 NaN    70
# Name: HI, dtype: int64
#
# k =  台北市 Series([], Name: County, dtype: int64)
#
# k =  台南市 Series([], Name: YYYY_WW, dtype: int64)
#
# k =  台南市 NaN    2
# Name: BI, dtype: int64
#
# k =  台南市 NaN    2
# Name: CI, dtype: int64
#
# k =  台南市 NaN    2
# Name: HI, dtype: int64
#
# k =  台南市 Series([], Name: County, dtype: int64)
#
# k =  台中市 Series([], Name: YYYY_WW, dtype: int64)
#
# k =  台中市 NaN    135
# Name: BI, dtype: int64
#
# k =  台中市 NaN    135
# Name: CI, dtype: int64
#
# k =  台中市 NaN    135
# Name: HI, dtype: int64
#
# k =  台中市 Series([], Name: County, dtype: int64)
#
# k =  金門縣 Series([], Name: YYYY_WW, dtype: int64)
#
# k =  金門縣 NaN    334
# Name: BI, dtype: int64
#
# k =  金門縣 NaN    334
# Name: CI, dtype: int64
#
# k =  金門縣 NaN    334
# Name: HI, dtype: int64
#
# k =  金門縣 Series([], Name: County, dtype: int64)
#
# k =  宜蘭縣 Series([], Name: YYYY_WW, dtype: int64)
#
# k =  宜蘭縣 NaN    72
# Name: BI, dtype: int64
#
# k =  宜蘭縣 NaN    72
# Name: CI, dtype: int64
#
# k =  宜蘭縣 NaN    72
# Name: HI, dtype: int64
#
# k =  宜蘭縣 Series([], Name: County, dtype: int64)
#
# k =  澎湖縣 Series([], Name: YYYY_WW, dtype: int64)
#
# k =  澎湖縣 NaN    100
# Name: BI, dtype: int64
#
# k =  澎湖縣 NaN    100
# Name: CI, dtype: int64
#
# k =  澎湖縣 NaN    100
# Name: HI, dtype: int64
#
# k =  澎湖縣 Series([], Name: County, dtype: int64)
#
# k =  連江縣 Series([], Name: YYYY_WW, dtype: int64)
#
# k =  連江縣 NaN    367
# Name: BI, dtype: int64
#
# k =  連江縣 NaN    367
# Name: CI, dtype: int64
#
# k =  連江縣 NaN    367
# Name: HI, dtype: int64
#
# k =  連江縣 Series([], Name: County, dtype: int64)

# %%
# Final step for BI, CI, HI
data_fin2['宜蘭縣'].tail()
# Out:
#      YYYY_WW        BI        CI        HI County
# 382  2019_18  0.412535  4.330298  0.386493    宜蘭縣
# 383  2019_19  0.412535  4.330298  0.386493    宜蘭縣
# 384  2019_20  0.412535  4.330298  0.386493    宜蘭縣
# 385  2019_21  0.412535  4.330298  0.386493    宜蘭縣
# 386  2019_22  0.412535  4.330298  0.386493    宜蘭縣

# %%
def convert_date_to_yyyy_ww(data_frame, yyyy_ww_dict):
    '''
    Input: data_frame
    Output: data_frame added yyyy_ww column
    '''
    yyww = []
    for i in range(data_frame.shape[0]):
        date_key = data_frame.Date[i]
        k = pd.to_datetime(date_key)
        yw = yyyy_ww_dict[k]
        yyww.append(yw)
        yyww = pd.DataFrame({'Year_Week': Year_Week})
        data_frame['Year_Week'] = yyww
        return data_frame

def groupby_yyyy_ww(data_frame, col = 'Year_Week'):
    tmp = data_frame.groupby(col, as_index = False).agg('mean') # groupby 'Year_Week' & do mean
    #tainan = data_fin2['台南市'].groupby('Year_Week', as_index = False).agg('mean')

    return tmp
    
    
def gen_full_time_table(data_frame, week_total, county = ''):
    '''
    Input: 
        data_frame: data with missing weeks of years
        week_total: total number of yyyy_ww 
    Output: 
        full_table: data_frame fulfilled missed yyyy_ww based on week_total
    
    '''
    
    full_table = []
    j = 0
    for i in range(len(week_total)):
        #print(i)

        yw_ref = week_total[i]
        
        try:
            yw_cty = sorted(data_frame.Year_Week)[j]
        except: IndexError
            
        #print(yw_cty)
        #print(j, yw_ref, yw_cty)

        if yw_ref == yw_cty:
            bi = data_frame.BI['mean'][j]
            ci = data_frame.CI['mean'][j]
            hi = data_frame.HI['mean'][j]
            full_table.append([yw_ref, bi, ci, hi])
            j += 1
            continue

        else:
            full_table.append([yw_ref,'NaN', 'NaN', 'NaN']) # float('nan'), float('nan'), float('nan')])
            continue
            
    full_table = pd.DataFrame(full_table, columns = ['YYYY_WW', 'BI', 'CI', 'HI'])
    full_table['County'] = county
    
    return full_table     

def find_missed_yyyy_ww(data_frame, week_total):
    a = set(data_frame.Year_Week)
    b = set(week_total)
    return b.difference(a)

# %% [markdown]
# ## Generate YYYY_WW data standard

# %%
from datetime import date,timedelta

# %%
df = pd.DataFrame({'INSP_DATE2':pd.date_range(start = '2012-01-01', end = '2019-5-31')})

a =  df['INSP_DATE2'] - pd.offsets.Week(weekday=6)
b =  df['INSP_DATE2'] + pd.offsets.Week(weekday=5)

m1 = df['INSP_DATE2'] != (a + pd.offsets.Week())
m2 = df['INSP_DATE2'] != (b - pd.offsets.Week())

df['c'] = df['INSP_DATE2'].mask(m1, a)
df['d'] = df['INSP_DATE2'].mask(m2, b)

df.tail()
#for i in range(df.shape[0]):
#    print(df.loc[i], '\n')
# Out:
#      INSP_DATE2          c          d
# 2703 2019-05-27 2019-05-26 2019-06-01
# 2704 2019-05-28 2019-05-26 2019-06-01
# 2705 2019-05-29 2019-05-26 2019-06-01
# 2706 2019-05-30 2019-05-26 2019-06-01
# 2707 2019-05-31 2019-05-26 2019-06-01

# %%
rows = []
w = 1 # start week
y = 2012 # start year

# generate standard yyyy_ww

for b in tqdm(range(0, 2755, 7)):

    row = []
    win = df.iloc[b : (b+7), :]
    date = win.c
    #print(str(date).split('-'))
    #y, _, _ = str(list(date)[0]).split('-')
    
       
    if w <10:
        w_str = '0' + str(w)
    else:
        w_str = str(w)
    win["Year_Week"] = str(y) + '_' + str(w_str)
    
    if y != 2014 and w == 52:
        w = 0
        y += 1
    elif y == 2014 and w == 53:
        w = 0
        y += 1
    w += 1
    
    rows.append(win)
# Out:
#   0%|          | 0/394 [00:00<?, ?it/s]/home/basic/tensorflow/tensorflow_pkg/tf_1.12_cuda10.0/lib/python3.5/site-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
#
#
#
#
#
#
#
#
#   0%|          | 1/394 [00:00<01:34,  4.15it/s]
#
#
#
#
#
#
#
#
#   1%|          | 2/394 [00:00<01:30,  4.33it/s]
#
#
#
#
#
#
#
#
#   1%|          | 3/394 [00:00<01:27,  4.48it/s]
#
#
#
#
#
#
#
#
#   1%|          | 4/394 [00:00<01:25,  4.58it/s]
#
#
#
#
#
#
#
#
#   1%|▏         | 5/394 [00:01<01:23,  4.64it/s]
#
#
#
#
#
#
#
#
#   2%|▏         | 6/394 [00:01<01:22,  4.69it/s]
#
#
#
#
#
#
#
#
#   2%|▏         | 7/394 [00:01<01:21,  4.73it/s]
#
#
#
#
#
#
#
#
#   2%|▏         | 8/394 [00:01<01:26,  4.45it/s]
#
#
#
#
#
#
#
#
#   2%|▏         | 9/394 [00:01<01:27,  4.39it/s]
#
#
#
#
#
#
#
#
#   3%|▎         | 10/394 [00:02<01:24,  4.52it/s]
#
#
#
#
#
#
#
#
#   3%|▎         | 11/394 [00:02<01:28,  4.32it/s]
#
#
#
#
#
#
#
#
#   3%|▎         | 12/394 [00:02<01:27,  4.36it/s]
#
#
#
#
#
#
#
#
#   3%|▎         | 13/394 [00:02<01:24,  4.48it/s]
#
#
#
#
#
#
#
#
#   4%|▎         | 14/394 [00:03<01:22,  4.62it/s]
#
#
#
#
#
#
#
#
#   4%|▍         | 15/394 [00:03<01:22,  4.57it/s]
#
#
#
#
#
#
#
#
#   4%|▍         | 16/394 [00:03<01:24,  4.48it/s]
#
#
#
#
#
#
#
#
#   4%|▍         | 17/394 [00:03<01:22,  4.58it/s]
#
#
#
#
#
#
#
#
#   5%|▍         | 18/394 [00:03<01:20,  4.65it/s]
#
#
#
#
#
#
#
#
#   5%|▍         | 19/394 [00:04<01:18,  4.75it/s]
#
#
#
#
#
#
#
#
#   5%|▌         | 20/394 [00:04<01:17,  4.82it/s]
#
#
#
#
#
#
#
#
#   5%|▌         | 21/394 [00:04<01:16,  4.86it/s]
#
#
#
#
#
#
#
#
#   6%|▌         | 22/394 [00:04<01:16,  4.89it/s]
#
#
#
#
#
#
#
#
#   6%|▌         | 23/394 [00:04<01:15,  4.91it/s]
#
#
#
#
#
#
#
#
#   6%|▌         | 24/394 [00:05<01:15,  4.92it/s]
#
#
#
#
#
#
#
#
#   6%|▋         | 25/394 [00:05<01:16,  4.84it/s]
#
#
#
#
#
#
#
#
#   7%|▋         | 26/394 [00:05<01:16,  4.80it/s]
#
#
#
#
#
#
#
#
#   7%|▋         | 27/394 [00:05<01:16,  4.79it/s]
#
#
#
#
#
#
#
#
#   7%|▋         | 28/394 [00:05<01:16,  4.80it/s]
#
#
#
#
#
#
#
#
#   7%|▋         | 29/394 [00:06<01:15,  4.80it/s]
#
#
#
#
#
#
#
#
#   8%|▊         | 30/394 [00:06<01:16,  4.78it/s]
#
#
#
#
#
#
#
#
#   8%|▊         | 31/394 [00:06<01:15,  4.83it/s]
#
#
#
#
#
#
#
#
#   8%|▊         | 32/394 [00:06<01:14,  4.86it/s]
#
#
#
#
#
#
#
#
#   8%|▊         | 33/394 [00:07<01:13,  4.90it/s]
#
#
#
#
#
#
#
#
#   9%|▊         | 34/394 [00:07<01:13,  4.91it/s]
#
#
#
#
#
#
#
#
#   9%|▉         | 35/394 [00:07<01:12,  4.94it/s]
#
#
#
#
#
#
#
#
#   9%|▉         | 36/394 [00:07<01:12,  4.95it/s]
#
#
#
#
#
#
#
#
#   9%|▉         | 37/394 [00:07<01:12,  4.94it/s]
#
#
#
#
#
#
#
#
#  10%|▉         | 38/394 [00:08<01:12,  4.94it/s]
#
#
#
#
#
#
#
#
#  10%|▉         | 39/394 [00:08<01:11,  4.95it/s]
#
#
#
#
#
#
#
#
#  10%|█         | 40/394 [00:08<01:11,  4.94it/s]
#
#
#
#
#
#
#
#
#  10%|█         | 41/394 [00:08<01:11,  4.95it/s]
#
#
#
#
#
#
#
#
#  11%|█         | 42/394 [00:08<01:10,  4.96it/s]
#
#
#
#
#
#
#
#
#  11%|█         | 43/394 [00:09<01:10,  4.95it/s]
#
#
#
#
#
#
#
#
#  11%|█         | 44/394 [00:09<01:10,  4.95it/s]
#
#
#
#
#
#
#
#
#  11%|█▏        | 45/394 [00:09<01:10,  4.96it/s]
#
#
#
#
#
#
#
#
#  12%|█▏        | 46/394 [00:09<01:10,  4.94it/s]
#
#
#
#
#
#
#
#
#  12%|█▏        | 47/394 [00:09<01:10,  4.95it/s]
#
#
#
#
#
#
#
#
#  12%|█▏        | 48/394 [00:10<01:09,  4.97it/s]
#
#
#
#
#
#
#
#
#  12%|█▏        | 49/394 [00:10<01:09,  4.97it/s]
#
#
#
#
#
#
#
#
#  13%|█▎        | 50/394 [00:10<01:09,  4.96it/s]
#
#
#
#
#
#
#
#
#  13%|█▎        | 51/394 [00:10<01:09,  4.97it/s]
#
#
#
#
#
#
#
#
#  13%|█▎        | 52/394 [00:10<01:09,  4.94it/s]
#
#
#
#
#
#
#
#
#  13%|█▎        | 53/394 [00:11<01:09,  4.91it/s]
#
#
#
#
#
#
#
#
#  14%|█▎        | 54/394 [00:11<01:09,  4.88it/s]
#
#
#
#
#
#
#
#
#  14%|█▍        | 55/394 [00:11<01:09,  4.88it/s]
#
#
#
#
#
#
#
#
#  14%|█▍        | 56/394 [00:11<01:08,  4.90it/s]
#
#
#
#
#
#
#
#
#  14%|█▍        | 57/394 [00:11<01:08,  4.91it/s]
#
#
#
#
#
#
#
#
#  15%|█▍        | 58/394 [00:12<01:08,  4.89it/s]
#
#
#
#
#
#
#
#
#  15%|█▍        | 59/394 [00:12<01:08,  4.90it/s]
#
#
#
#
#
#
#
#
#  15%|█▌        | 60/394 [00:12<01:07,  4.93it/s]
#
#
#
#
#
#
#
#
#  15%|█▌        | 61/394 [00:12<01:08,  4.87it/s]
#
#
#
#
#
#
#
#
#  16%|█▌        | 62/394 [00:12<01:13,  4.49it/s]
#
#
#
#
#
#
#
#
#  16%|█▌        | 63/394 [00:13<01:12,  4.57it/s]
#
#
#
#
#
#
#
#
#  16%|█▌        | 64/394 [00:13<01:11,  4.60it/s]
#
#
#
#
#
#
#
#
#  16%|█▋        | 65/394 [00:13<01:10,  4.64it/s]
#
#
#
#
#
#
#
#
#  17%|█▋        | 66/394 [00:13<01:14,  4.40it/s]
#
#
#
#
#
#
#
#
#  17%|█▋        | 67/394 [00:14<01:13,  4.48it/s]
#
#
#
#
#
#
#
#
#  17%|█▋        | 68/394 [00:14<01:15,  4.30it/s]
#
#
#
#
#
#
#
#
#  18%|█▊        | 69/394 [00:14<01:13,  4.45it/s]
#
#
#
#
#
#
#
#
#  18%|█▊        | 70/394 [00:14<01:13,  4.41it/s]
#
#
#
#
#
#
#
#
#  18%|█▊        | 71/394 [00:15<01:15,  4.25it/s]
#
#
#
#
#
#
#
#
#  18%|█▊        | 72/394 [00:15<01:13,  4.41it/s]
#
#
#
#
#
#
#
#
#  19%|█▊        | 73/394 [00:15<01:16,  4.18it/s]
#
#
#
#
#
#
#
#
#  19%|█▉        | 74/394 [00:15<01:13,  4.37it/s]
#
#
#
#
#
#
#
#
#  19%|█▉        | 75/394 [00:15<01:10,  4.53it/s]
#
#
#
#
#
#
#
#
#  19%|█▉        | 76/394 [00:16<01:08,  4.64it/s]
#
#
#
#
#
#
#
#
#  20%|█▉        | 77/394 [00:16<01:06,  4.75it/s]
#
#
#
#
#
#
#
#
#  20%|█▉        | 78/394 [00:16<01:05,  4.83it/s]
#
#
#
#
#
#
#
#
#  20%|██        | 79/394 [00:16<01:04,  4.86it/s]
#
#
#
#
#
#
#
#
#  20%|██        | 80/394 [00:16<01:04,  4.90it/s]
#
#
#
#
#
#
#
#
#  21%|██        | 81/394 [00:17<01:03,  4.90it/s]
#
#
#
#
#
#
#
#
#  21%|██        | 82/394 [00:17<01:04,  4.86it/s]
#
#
#
#
#
#
#
#
#  21%|██        | 83/394 [00:17<01:04,  4.81it/s]
#
#
#
#
#
#
#
#
#  21%|██▏       | 84/394 [00:17<01:04,  4.79it/s]
#
#
#
#
#
#
#
#
#  22%|██▏       | 85/394 [00:17<01:04,  4.79it/s]
#
#
#
#
#
#
#
#
#  22%|██▏       | 86/394 [00:18<01:03,  4.82it/s]
#
#
#
#
#
#
#
#
#  22%|██▏       | 87/394 [00:18<01:03,  4.83it/s]
#
#
#
#
#
#
#
#
#  22%|██▏       | 88/394 [00:18<01:03,  4.84it/s]
#
#
#
#
#
#
#
#
#  23%|██▎       | 89/394 [00:18<01:03,  4.78it/s]
#
#
#
#
#
#
#
#
#  23%|██▎       | 90/394 [00:18<01:02,  4.85it/s]
#
#
#
#
#
#
#
#
#  23%|██▎       | 91/394 [00:19<01:02,  4.89it/s]
#
#
#
#
#
#
#
#
#  23%|██▎       | 92/394 [00:19<01:01,  4.93it/s]
#
#
#
#
#
#
#
#
#  24%|██▎       | 93/394 [00:19<01:00,  4.94it/s]
#
#
#
#
#
#
#
#
#  24%|██▍       | 94/394 [00:19<01:00,  4.93it/s]
#
#
#
#
#
#
#
#
#  24%|██▍       | 95/394 [00:19<01:00,  4.94it/s]
#
#
#
#
#
#
#
#
#  24%|██▍       | 96/394 [00:20<01:00,  4.93it/s]
#
#
#
#
#
#
#
#
#  25%|██▍       | 97/394 [00:20<01:00,  4.94it/s]
#
#
#
#
#
#
#
#
#  25%|██▍       | 98/394 [00:20<00:59,  4.95it/s]
#
#
#
#
#
#
#
#
#  25%|██▌       | 99/394 [00:20<00:59,  4.94it/s]
#
#
#
#
#
#
#
#
#  25%|██▌       | 100/394 [00:20<00:59,  4.92it/s]
#
#
#
#
#
#
#
#
#  26%|██▌       | 101/394 [00:21<00:59,  4.89it/s]
#
#
#
#
#
#
#
#
#  26%|██▌       | 102/394 [00:21<00:59,  4.92it/s]
#
#
#
#
#
#
#
#
#  26%|██▌       | 103/394 [00:21<00:59,  4.90it/s]
#
#
#
#
#
#
#
#
#  26%|██▋       | 104/394 [00:21<00:59,  4.88it/s]
#
#
#
#
#
#
#
#
#  27%|██▋       | 105/394 [00:22<00:58,  4.91it/s]
#
#
#
#
#
#
#
#
#  27%|██▋       | 106/394 [00:22<00:58,  4.88it/s]
#
#
#
#
#
#
#
#
#  27%|██▋       | 107/394 [00:22<00:59,  4.86it/s]
#
#
#
#
#
#
#
#
#  27%|██▋       | 108/394 [00:22<00:59,  4.84it/s]
#
#
#
#
#
#
#
#
#  28%|██▊       | 109/394 [00:22<00:58,  4.87it/s]
#
#
#
#
#
#
#
#
#  28%|██▊       | 110/394 [00:23<00:58,  4.89it/s]
#
#
#
#
#
#
#
#
#  28%|██▊       | 111/394 [00:23<00:58,  4.84it/s]
#
#
#
#
#
#
#
#
#  28%|██▊       | 112/394 [00:23<00:58,  4.85it/s]
#
#
#
#
#
#
#
#
#  29%|██▊       | 113/394 [00:23<00:57,  4.89it/s]
#
#
#
#
#
#
#
#
#  29%|██▉       | 114/394 [00:23<00:57,  4.89it/s]
#
#
#
#
#
#
#
#
#  29%|██▉       | 115/394 [00:24<00:57,  4.86it/s]
#
#
#
#
#
#
#
#
#  29%|██▉       | 116/394 [00:24<00:57,  4.86it/s]
#
#
#
#
#
#
#
#
#  30%|██▉       | 117/394 [00:24<00:57,  4.85it/s]
#
#
#
#
#
#
#
#
#  30%|██▉       | 118/394 [00:24<00:56,  4.88it/s]
#
#
#
#
#
#
#
#
#  30%|███       | 119/394 [00:24<00:56,  4.90it/s]
#
#
#
#
#
#
#
#
#  30%|███       | 120/394 [00:25<00:56,  4.86it/s]
#
#
#
#
#
#
#
#
#  31%|███       | 121/394 [00:25<00:55,  4.88it/s]
#
#
#
#
#
#
#
#
#  31%|███       | 122/394 [00:25<00:55,  4.88it/s]
#
#
#
#
#
#
#
#
#  31%|███       | 123/394 [00:25<00:55,  4.90it/s]
#
#
#
#
#
#
#
#
#  31%|███▏      | 124/394 [00:25<00:54,  4.92it/s]
#
#
#
#
#
#
#
#
#  32%|███▏      | 125/394 [00:26<00:55,  4.86it/s]
#
#
#
#
#
#
#
#
#  32%|███▏      | 126/394 [00:26<00:55,  4.85it/s]
#
#
#
#
#
#
#
#
#  32%|███▏      | 127/394 [00:26<00:54,  4.86it/s]
#
#
#
#
#
#
#
#
#  32%|███▏      | 128/394 [00:26<00:54,  4.88it/s]
#
#
#
#
#
#
#
#
#  33%|███▎      | 129/394 [00:26<00:54,  4.82it/s]
#
#
#
#
#
#
#
#
#  33%|███▎      | 130/394 [00:27<00:55,  4.77it/s]
#
#
#
#
#
#
#
#
#  33%|███▎      | 131/394 [00:27<00:55,  4.77it/s]
#
#
#
#
#
#
#
#
#  34%|███▎      | 132/394 [00:27<00:54,  4.79it/s]
#
#
#
#
#
#
#
#
#  34%|███▍      | 133/394 [00:27<00:54,  4.77it/s]
#
#
#
#
#
#
#
#
#  34%|███▍      | 134/394 [00:28<00:54,  4.79it/s]
#
#
#
#
#
#
#
#
#  34%|███▍      | 135/394 [00:28<00:54,  4.78it/s]
#
#
#
#
#
#
#
#
#  35%|███▍      | 136/394 [00:28<00:53,  4.80it/s]
#
#
#
#
#
#
#
#
#  35%|███▍      | 137/394 [00:28<00:53,  4.78it/s]
#
#
#
#
#
#
#
#
#  35%|███▌      | 138/394 [00:28<00:53,  4.75it/s]
#
#
#
#
#
#
#
#
#  35%|███▌      | 139/394 [00:29<00:53,  4.74it/s]
#
#
#
#
#
#
#
#
#  36%|███▌      | 140/394 [00:29<00:53,  4.75it/s]
#
#
#
#
#
#
#
#
#  36%|███▌      | 141/394 [00:29<00:53,  4.71it/s]
#
#
#
#
#
#
#
#
#  36%|███▌      | 142/394 [00:29<00:53,  4.75it/s]
#
#
#
#
#
#
#
#
#  36%|███▋      | 143/394 [00:29<00:52,  4.78it/s]
#
#
#
#
#
#
#
#
#  37%|███▋      | 144/394 [00:30<00:52,  4.74it/s]
#
#
#
#
#
#
#
#
#  37%|███▋      | 145/394 [00:30<00:52,  4.71it/s]
#
#
#
#
#
#
#
#
#  37%|███▋      | 146/394 [00:30<00:52,  4.75it/s]
#
#
#
#
#
#
#
#
#  37%|███▋      | 147/394 [00:30<00:51,  4.77it/s]
#
#
#
#
#
#
#
#
#  38%|███▊      | 148/394 [00:30<00:51,  4.79it/s]
#
#
#
#
#
#
#
#
#  38%|███▊      | 149/394 [00:31<00:51,  4.80it/s]
#
#
#
#
#
#
#
#
#  38%|███▊      | 150/394 [00:31<00:51,  4.77it/s]
#
#
#
#
#
#
#
#
#  38%|███▊      | 151/394 [00:31<00:50,  4.77it/s]
#
#
#
#
#
#
#
#
#  39%|███▊      | 152/394 [00:31<00:50,  4.77it/s]
#
#
#
#
#
#
#
#
#  39%|███▉      | 153/394 [00:31<00:50,  4.82it/s]
#
#
#
#
#
#
#
#
#  39%|███▉      | 154/394 [00:32<00:49,  4.85it/s]
#
#
#
#
#
#
#
#
#  39%|███▉      | 155/394 [00:32<00:49,  4.84it/s]
#
#
#
#
#
#
#
#
#  40%|███▉      | 156/394 [00:32<00:48,  4.87it/s]
#
#
#
#
#
#
#
#
#  40%|███▉      | 157/394 [00:32<00:48,  4.89it/s]
#
#
#
#
#
#
#
#
#  40%|████      | 158/394 [00:33<00:48,  4.85it/s]
#
#
#
#
#
#
#
#
#  40%|████      | 159/394 [00:33<00:48,  4.88it/s]
#
#
#
#
#
#
#
#
#  41%|████      | 160/394 [00:33<00:47,  4.88it/s]
#
#
#
#
#
#
#
#
#  41%|████      | 161/394 [00:33<00:47,  4.90it/s]
#
#
#
#
#
#
#
#
#  41%|████      | 162/394 [00:33<00:47,  4.91it/s]
#
#
#
#
#
#
#
#
#  41%|████▏     | 163/394 [00:34<00:46,  4.92it/s]
#
#
#
#
#
#
#
#
#  42%|████▏     | 164/394 [00:34<00:46,  4.91it/s]
#
#
#
#
#
#
#
#
#  42%|████▏     | 165/394 [00:34<00:46,  4.93it/s]
#
#
#
#
#
#
#
#
#  42%|████▏     | 166/394 [00:34<00:46,  4.94it/s]
#
#
#
#
#
#
#
#
#  42%|████▏     | 167/394 [00:34<00:46,  4.93it/s]
#
#
#
#
#
#
#
#
#  43%|████▎     | 168/394 [00:35<00:46,  4.90it/s]
#
#
#
#
#
#
#
#
#  43%|████▎     | 169/394 [00:35<00:46,  4.85it/s]
#
#
#
#
#
#
#
#
#  43%|████▎     | 170/394 [00:35<00:46,  4.82it/s]
#
#
#
#
#
#
#
#
#  43%|████▎     | 171/394 [00:35<00:46,  4.83it/s]
#
#
#
#
#
#
#
#
#  44%|████▎     | 172/394 [00:35<00:46,  4.80it/s]
#
#
#
#
#
#
#
#
#  44%|████▍     | 173/394 [00:36<00:46,  4.78it/s]
#
#
#
#
#
#
#
#
#  44%|████▍     | 174/394 [00:36<00:45,  4.84it/s]
#
#
#
#
#
#
#
#
#  44%|████▍     | 175/394 [00:36<00:45,  4.86it/s]
#
#
#
#
#
#
#
#
#  45%|████▍     | 176/394 [00:36<00:44,  4.90it/s]
#
#
#
#
#
#
#
#
#  45%|████▍     | 177/394 [00:36<00:44,  4.87it/s]
#
#
#
#
#
#
#
#
#  45%|████▌     | 178/394 [00:37<00:44,  4.86it/s]
#
#
#
#
#
#
#
#
#  45%|████▌     | 179/394 [00:37<00:44,  4.87it/s]
#
#
#
#
#
#
#
#
#  46%|████▌     | 180/394 [00:37<00:43,  4.87it/s]
#
#
#
#
#
#
#
#
#  46%|████▌     | 181/394 [00:37<00:44,  4.80it/s]
#
#
#
#
#
#
#
#
#  46%|████▌     | 182/394 [00:37<00:43,  4.84it/s]
#
#
#
#
#
#
#
#
#  46%|████▋     | 183/394 [00:38<00:44,  4.76it/s]
#
#
#
#
#
#
#
#
#  47%|████▋     | 184/394 [00:38<00:44,  4.76it/s]
#
#
#
#
#
#
#
#
#  47%|████▋     | 185/394 [00:38<00:43,  4.79it/s]
#
#
#
#
#
#
#
#
#  47%|████▋     | 186/394 [00:38<00:43,  4.79it/s]
#
#
#
#
#
#
#
#
#  47%|████▋     | 187/394 [00:38<00:43,  4.77it/s]
#
#
#
#
#
#
#
#
#  48%|████▊     | 188/394 [00:39<00:43,  4.77it/s]
#  48%|████▊     | 189/394 [00:39<00:43,  4.77it/s]
#
#
#
#
#
#
#
#
#  48%|████▊     | 190/394 [00:39<00:42,  4.77it/s]
#
#
#
#
#
#
#
#
#  48%|████▊     | 191/394 [00:39<00:42,  4.83it/s]
#
#
#
#
#
#
#
#
#  49%|████▊     | 192/394 [00:40<00:41,  4.85it/s]
#
#
#
#
#
#
#
#
#  49%|████▉     | 193/394 [00:40<00:41,  4.85it/s]
#
#
#
#
#
#
#
#
#  49%|████▉     | 194/394 [00:40<00:40,  4.89it/s]
#
#
#
#
#
#
#
#
#  49%|████▉     | 195/394 [00:40<00:40,  4.91it/s]
#
#
#
#
#
#
#
#
#  50%|████▉     | 196/394 [00:40<00:40,  4.89it/s]
#
#
#
#
#
#
#
#
#  50%|█████     | 197/394 [00:41<00:40,  4.90it/s]
#
#
#
#
#
#
#
#
#  50%|█████     | 198/394 [00:41<00:40,  4.89it/s]
#
#
#
#
#
#
#
#
#  51%|█████     | 199/394 [00:41<00:40,  4.87it/s]
#
#
#
#
#
#
#
#
#  51%|█████     | 200/394 [00:41<00:39,  4.89it/s]
#
#
#
#
#
#
#
#
#  51%|█████     | 201/394 [00:41<00:39,  4.88it/s]
#
#
#
#
#
#
#
#
#  51%|█████▏    | 202/394 [00:42<00:39,  4.84it/s]
#
#
#
#
#
#
#
#
#  52%|█████▏    | 203/394 [00:42<00:39,  4.83it/s]
#
#
#
#
#
#
#
#
#  52%|█████▏    | 204/394 [00:42<00:39,  4.84it/s]
#
#
#
#
#
#
#
#
#  52%|█████▏    | 205/394 [00:42<00:39,  4.83it/s]
#
#
#
#
#
#
#
#
#  52%|█████▏    | 206/394 [00:42<00:38,  4.84it/s]
#
#
#
#
#
#
#
#
#  53%|█████▎    | 207/394 [00:43<00:38,  4.86it/s]
#
#
#
#
#
#
#
#
#  53%|█████▎    | 208/394 [00:43<00:38,  4.85it/s]
#
#
#
#
#
#
#
#
#  53%|█████▎    | 209/394 [00:43<00:38,  4.85it/s]
#
#
#
#
#
#
#
#
#  53%|█████▎    | 210/394 [00:43<00:37,  4.85it/s]
#
#
#
#
#
#
#
#
#  54%|█████▎    | 211/394 [00:43<00:37,  4.88it/s]
#
#
#
#
#
#
#
#
#  54%|█████▍    | 212/394 [00:44<00:37,  4.90it/s]
#
#
#
#
#
#
#
#
#  54%|█████▍    | 213/394 [00:44<00:37,  4.89it/s]
#
#
#
#
#
#
#
#
#  54%|█████▍    | 214/394 [00:44<00:36,  4.90it/s]
#
#
#
#
#
#
#
#
#  55%|█████▍    | 215/394 [00:44<00:36,  4.89it/s]
#
#
#
#
#
#
#
#
#  55%|█████▍    | 216/394 [00:44<00:36,  4.89it/s]
#
#
#
#
#
#
#
#
#  55%|█████▌    | 217/394 [00:45<00:36,  4.88it/s]
#
#
#
#
#
#
#
#
#  55%|█████▌    | 218/394 [00:45<00:36,  4.80it/s]
#
#
#
#
#
#
#
#
#  56%|█████▌    | 219/394 [00:45<00:36,  4.84it/s]
#
#
#
#
#
#
#
#
#  56%|█████▌    | 220/394 [00:45<00:35,  4.85it/s]
#
#
#
#
#
#
#
#
#  56%|█████▌    | 221/394 [00:45<00:35,  4.84it/s]
#
#
#
#
#
#
#
#
#  56%|█████▋    | 222/394 [00:46<00:35,  4.80it/s]
#
#
#
#
#
#
#
#
#  57%|█████▋    | 223/394 [00:46<00:35,  4.79it/s]
#
#
#
#
#
#
#
#
#  57%|█████▋    | 224/394 [00:46<00:36,  4.64it/s]
#
#
#
#
#
#
#
#
#  57%|█████▋    | 225/394 [00:46<00:35,  4.72it/s]
#
#
#
#
#
#
#
#
#  57%|█████▋    | 226/394 [00:47<00:35,  4.78it/s]
#
#
#
#
#
#
#
#
#  58%|█████▊    | 227/394 [00:47<00:34,  4.82it/s]
#
#
#
#
#
#
#
#
#  58%|█████▊    | 228/394 [00:47<00:34,  4.76it/s]
#
#
#
#
#
#
#
#
#  58%|█████▊    | 229/394 [00:47<00:34,  4.79it/s]
#
#
#
#
#
#
#
#
#  58%|█████▊    | 230/394 [00:47<00:34,  4.76it/s]
#
#
#
#
#
#
#
#
#  59%|█████▊    | 231/394 [00:48<00:34,  4.77it/s]
#
#
#
#
#
#
#
#
#  59%|█████▉    | 232/394 [00:48<00:34,  4.75it/s]
#
#
#
#
#
#
#
#
#  59%|█████▉    | 233/394 [00:48<00:34,  4.66it/s]
#
#
#
#
#
#
#
#
#  59%|█████▉    | 234/394 [00:48<00:36,  4.43it/s]
#
#
#
#
#
#
#
#
#  60%|█████▉    | 235/394 [00:49<00:35,  4.44it/s]
#
#
#
#
#
#
#
#
#  60%|█████▉    | 236/394 [00:49<00:37,  4.26it/s]
#
#
#
#
#
#
#
#
#  60%|██████    | 237/394 [00:49<00:36,  4.36it/s]
#
#
#
#
#
#
#
#
#  60%|██████    | 238/394 [00:49<00:34,  4.47it/s]
#
#
#
#
#
#
#
#
#  61%|██████    | 239/394 [00:49<00:34,  4.54it/s]
#
#
#
#
#
#
#
#
#  61%|██████    | 240/394 [00:50<00:33,  4.60it/s]
#
#
#
#
#
#
#
#
#  61%|██████    | 241/394 [00:50<00:32,  4.65it/s]
#
#
#
#
#
#
#
#
#  61%|██████▏   | 242/394 [00:50<00:32,  4.67it/s]
#
#
#
#
#
#
#
#
#  62%|██████▏   | 243/394 [00:50<00:32,  4.68it/s]
#
#
#
#
#
#
#
#
#  62%|██████▏   | 244/394 [00:50<00:32,  4.68it/s]
#
#
#
#
#
#
#
#
#  62%|██████▏   | 245/394 [00:51<00:31,  4.73it/s]
#
#
#
#
#
#
#
#
#  62%|██████▏   | 246/394 [00:51<00:31,  4.65it/s]
#
#
#
#
#
#
#
#
#  63%|██████▎   | 247/394 [00:51<00:33,  4.44it/s]
#
#
#
#
#
#
#
#
#  63%|██████▎   | 248/394 [00:51<00:34,  4.27it/s]
#
#
#
#
#
#
#
#
#  63%|██████▎   | 249/394 [00:52<00:34,  4.18it/s]
#
#
#
#
#
#
#
#
#  63%|██████▎   | 250/394 [00:52<00:34,  4.19it/s]
#
#
#
#
#
#
#
#
#  64%|██████▎   | 251/394 [00:52<00:32,  4.37it/s]
#
#
#
#
#
#
#
#
#  64%|██████▍   | 252/394 [00:52<00:31,  4.46it/s]
#
#
#
#
#
#
#
#
#  64%|██████▍   | 253/394 [00:53<00:31,  4.52it/s]
#
#
#
#
#
#
#
#
#  64%|██████▍   | 254/394 [00:53<00:30,  4.57it/s]
#
#
#
#
#
#
#
#
#  65%|██████▍   | 255/394 [00:53<00:30,  4.62it/s]
#
#
#
#
#
#
#
#
#  65%|██████▍   | 256/394 [00:53<00:30,  4.56it/s]
#
#
#
#
#
#
#
#
#  65%|██████▌   | 257/394 [00:53<00:30,  4.45it/s]
#
#
#
#
#
#
#
#
#  65%|██████▌   | 258/394 [00:54<00:30,  4.48it/s]
#
#
#
#
#
#
#
#
#  66%|██████▌   | 259/394 [00:54<00:29,  4.54it/s]
#
#
#
#
#
#
#
#
#  66%|██████▌   | 260/394 [00:54<00:30,  4.33it/s]
#
#
#
#
#
#
#
#
#  66%|██████▌   | 261/394 [00:54<00:30,  4.43it/s]
#
#
#
#
#
#
#
#
#  66%|██████▋   | 262/394 [00:55<00:29,  4.48it/s]
#
#
#
#
#
#
#
#
#  67%|██████▋   | 263/394 [00:55<00:30,  4.24it/s]
#
#
#
#
#
#
#
#
#  67%|██████▋   | 264/394 [00:55<00:29,  4.38it/s]
#
#
#
#
#
#
#
#
#  67%|██████▋   | 265/394 [00:55<00:28,  4.48it/s]
#
#
#
#
#
#
#
#
#  68%|██████▊   | 266/394 [00:55<00:27,  4.60it/s]
#
#
#
#
#
#
#
#
#  68%|██████▊   | 267/394 [00:56<00:27,  4.66it/s]
#
#
#
#
#
#
#
#
#  68%|██████▊   | 268/394 [00:56<00:26,  4.70it/s]
#
#
#
#
#
#
#
#
#  68%|██████▊   | 269/394 [00:56<00:26,  4.73it/s]
#
#
#
#
#
#
#
#
#  69%|██████▊   | 270/394 [00:56<00:26,  4.76it/s]
#
#
#
#
#
#
#
#
#  69%|██████▉   | 271/394 [00:56<00:25,  4.77it/s]
#
#
#
#
#
#
#
#
#  69%|██████▉   | 272/394 [00:57<00:25,  4.79it/s]
#
#
#
#
#
#
#
#
#  69%|██████▉   | 273/394 [00:57<00:25,  4.80it/s]
#
#
#
#
#
#
#
#
#  70%|██████▉   | 274/394 [00:57<00:24,  4.80it/s]
#
#
#
#
#
#
#
#
#  70%|██████▉   | 275/394 [00:57<00:24,  4.83it/s]
#
#
#
#
#
#
#
#
#  70%|███████   | 276/394 [00:57<00:24,  4.81it/s]
#
#
#
#
#
#
#
#
#  70%|███████   | 277/394 [00:58<00:24,  4.80it/s]
#
#
#
#
#
#
#
#
#  71%|███████   | 278/394 [00:58<00:24,  4.80it/s]
#
#
#
#
#
#
#
#
#  71%|███████   | 279/394 [00:58<00:23,  4.80it/s]
#
#
#
#
#
#
#
#
#  71%|███████   | 280/394 [00:58<00:23,  4.84it/s]
#
#
#
#
#
#
#
#
#  71%|███████▏  | 281/394 [00:59<00:23,  4.83it/s]
#
#
#
#
#
#
#
#
#  72%|███████▏  | 282/394 [00:59<00:23,  4.83it/s]
#
#
#
#
#
#
#
#
#  72%|███████▏  | 283/394 [00:59<00:22,  4.83it/s]
#
#
#
#
#
#
#
#
#  72%|███████▏  | 284/394 [00:59<00:22,  4.86it/s]
#
#
#
#
#
#
#
#
#  72%|███████▏  | 285/394 [00:59<00:23,  4.65it/s]
#
#
#
#
#
#
#
#
#  73%|███████▎  | 286/394 [01:00<00:23,  4.64it/s]
#
#
#
#
#
#
#
#
#  73%|███████▎  | 287/394 [01:00<00:22,  4.72it/s]
#
#
#
#
#
#
#
#
#  73%|███████▎  | 288/394 [01:00<00:22,  4.78it/s]
#
#
#
#
#
#
#
#
#  73%|███████▎  | 289/394 [01:00<00:21,  4.84it/s]
#
#
#
#
#
#
#
#
#  74%|███████▎  | 290/394 [01:00<00:21,  4.88it/s]
#
#
#
#
#
#
#
#
#  74%|███████▍  | 291/394 [01:01<00:21,  4.89it/s]
#
#
#
#
#
#
#
#
#  74%|███████▍  | 292/394 [01:01<00:20,  4.91it/s]
#
#
#
#
#
#
#
#
#  74%|███████▍  | 293/394 [01:01<00:20,  4.93it/s]
#
#
#
#
#
#
#
#
#  75%|███████▍  | 294/394 [01:01<00:20,  4.92it/s]
#
#
#
#
#
#
#
#
#  75%|███████▍  | 295/394 [01:01<00:20,  4.84it/s]
#
#
#
#
#
#
#
#
#  75%|███████▌  | 296/394 [01:02<00:20,  4.79it/s]
#
#
#
#
#
#
#
#
#  75%|███████▌  | 297/394 [01:02<00:20,  4.72it/s]
#
#
#
#
#
#
#
#
#  76%|███████▌  | 298/394 [01:02<00:21,  4.39it/s]
#
#
#
#
#
#
#
#
#  76%|███████▌  | 299/394 [01:02<00:20,  4.54it/s]
#
#
#
#
#
#
#
#
#  76%|███████▌  | 300/394 [01:03<00:20,  4.65it/s]
#
#
#
#
#
#
#
#
#  76%|███████▋  | 301/394 [01:03<00:19,  4.66it/s]
#
#
#
#
#
#
#
#
#  77%|███████▋  | 302/394 [01:03<00:19,  4.65it/s]
#
#
#
#
#
#
#
#
#  77%|███████▋  | 303/394 [01:03<00:19,  4.68it/s]
#
#
#
#
#
#
#
#
#  77%|███████▋  | 304/394 [01:03<00:19,  4.70it/s]
#
#
#
#
#
#
#
#
#  77%|███████▋  | 305/394 [01:04<00:18,  4.71it/s]
#
#
#
#
#
#
#
#
#  78%|███████▊  | 306/394 [01:04<00:18,  4.78it/s]
#
#
#
#
#
#
#
#
#  78%|███████▊  | 307/394 [01:04<00:18,  4.81it/s]
#
#
#
#
#
#
#
#
#  78%|███████▊  | 308/394 [01:04<00:18,  4.69it/s]
#
#
#
#
#
#
#
#
#  78%|███████▊  | 309/394 [01:04<00:17,  4.76it/s]
#
#
#
#
#
#
#
#
#  79%|███████▊  | 310/394 [01:05<00:17,  4.79it/s]
#
#
#
#
#
#
#
#
#  79%|███████▉  | 311/394 [01:05<00:17,  4.83it/s]
#
#
#
#
#
#
#
#
#  79%|███████▉  | 312/394 [01:05<00:16,  4.87it/s]
#
#
#
#
#
#
#
#
#  79%|███████▉  | 313/394 [01:05<00:16,  4.88it/s]
#
#
#
#
#
#
#
#
#  80%|███████▉  | 314/394 [01:05<00:16,  4.90it/s]
#
#
#
#
#
#
#
#
#  80%|███████▉  | 315/394 [01:06<00:16,  4.91it/s]
#
#
#
#
#
#
#
#
#  80%|████████  | 316/394 [01:06<00:15,  4.92it/s]
#
#
#
#
#
#
#
#
#  80%|████████  | 317/394 [01:06<00:15,  4.96it/s]
#
#
#
#
#
#
#
#
#  81%|████████  | 318/394 [01:06<00:15,  4.93it/s]
#
#
#
#
#
#
#
#
#  81%|████████  | 319/394 [01:06<00:15,  4.96it/s]
#
#
#
#
#
#
#
#
#  81%|████████  | 320/394 [01:07<00:14,  4.95it/s]
#
#
#
#
#
#
#
#
#  81%|████████▏ | 321/394 [01:07<00:14,  4.94it/s]
#
#
#
#
#
#
#
#
#  82%|████████▏ | 322/394 [01:07<00:14,  4.94it/s]
#
#
#
#
#
#
#
#
#  82%|████████▏ | 323/394 [01:07<00:14,  4.95it/s]
#
#
#
#
#
#
#
#
#  82%|████████▏ | 324/394 [01:07<00:14,  4.95it/s]
#
#
#
#
#
#
#
#
#  82%|████████▏ | 325/394 [01:08<00:13,  4.94it/s]
#
#
#
#
#
#
#
#
#  83%|████████▎ | 326/394 [01:08<00:13,  4.94it/s]
#
#
#
#
#
#
#
#
#  83%|████████▎ | 327/394 [01:08<00:13,  4.94it/s]
#
#
#
#
#
#
#
#
#  83%|████████▎ | 328/394 [01:08<00:13,  4.93it/s]
#
#
#
#
#
#
#
#
#  84%|████████▎ | 329/394 [01:08<00:13,  4.94it/s]
#
#
#
#
#
#
#
#
#  84%|████████▍ | 330/394 [01:09<00:13,  4.92it/s]
#
#
#
#
#
#
#
#
#  84%|████████▍ | 331/394 [01:09<00:12,  4.92it/s]
#
#
#
#
#
#
#
#
#  84%|████████▍ | 332/394 [01:09<00:12,  4.93it/s]
#
#
#
#
#
#
#
#
#  85%|████████▍ | 333/394 [01:09<00:12,  4.93it/s]
#
#
#
#
#
#
#
#
#  85%|████████▍ | 334/394 [01:10<00:12,  4.91it/s]
#
#
#
#
#
#
#
#
#  85%|████████▌ | 335/394 [01:10<00:12,  4.86it/s]
#
#
#
#
#
#
#
#
#  85%|████████▌ | 336/394 [01:10<00:11,  4.87it/s]
#
#
#
#
#
#
#
#
#  86%|████████▌ | 337/394 [01:10<00:11,  4.87it/s]
#
#
#
#
#
#
#
#
#  86%|████████▌ | 338/394 [01:10<00:11,  4.87it/s]
#
#
#
#
#
#
#
#
#  86%|████████▌ | 339/394 [01:11<00:11,  4.87it/s]
#
#
#
#
#
#
#
#
#  86%|████████▋ | 340/394 [01:11<00:11,  4.84it/s]
#
#
#
#
#
#
#
#
#  87%|████████▋ | 341/394 [01:11<00:10,  4.85it/s]
#
#
#
#
#
#
#
#
#  87%|████████▋ | 342/394 [01:11<00:10,  4.88it/s]
#
#
#
#
#
#
#
#
#  87%|████████▋ | 343/394 [01:11<00:10,  4.91it/s]
#
#
#
#
#
#
#
#
#  87%|████████▋ | 344/394 [01:12<00:10,  4.92it/s]
#
#
#
#
#
#
#
#
#  88%|████████▊ | 345/394 [01:12<00:09,  4.95it/s]
#
#
#
#
#
#
#
#
#  88%|████████▊ | 346/394 [01:12<00:09,  4.96it/s]
#
#
#
#
#
#
#
#
#  88%|████████▊ | 347/394 [01:12<00:09,  4.95it/s]
#
#
#
#
#
#
#
#
#  88%|████████▊ | 348/394 [01:12<00:09,  4.96it/s]
#
#
#
#
#
#
#
#
#  89%|████████▊ | 349/394 [01:13<00:09,  4.95it/s]
#
#
#
#
#
#
#
#
#  89%|████████▉ | 350/394 [01:13<00:08,  4.94it/s]
#
#
#
#
#
#
#
#
#  89%|████████▉ | 351/394 [01:13<00:08,  4.94it/s]
#
#
#
#
#
#
#
#
#  89%|████████▉ | 352/394 [01:13<00:08,  4.95it/s]
#
#
#
#
#
#
#
#
#  90%|████████▉ | 353/394 [01:13<00:08,  4.95it/s]
#
#
#
#
#
#
#
#
#  90%|████████▉ | 354/394 [01:14<00:08,  4.97it/s]
#
#
#
#
#
#
#
#
#  90%|█████████ | 355/394 [01:14<00:07,  4.97it/s]
#
#
#
#
#
#
#
#
#  90%|█████████ | 356/394 [01:14<00:07,  4.99it/s]
#
#
#
#
#
#
#
#
#  91%|█████████ | 357/394 [01:14<00:07,  4.98it/s]
#
#
#
#
#
#
#
#
#  91%|█████████ | 358/394 [01:14<00:07,  4.96it/s]
#
#
#
#
#
#
#
#
#  91%|█████████ | 359/394 [01:15<00:07,  4.96it/s]
#
#
#
#
#
#
#
#
#  91%|█████████▏| 360/394 [01:15<00:06,  4.95it/s]
#
#
#
#
#
#
#
#
#  92%|█████████▏| 361/394 [01:15<00:06,  4.95it/s]
#
#
#
#
#
#
#
#
#  92%|█████████▏| 362/394 [01:15<00:06,  4.95it/s]
#
#
#
#
#
#
#
#
#  92%|█████████▏| 363/394 [01:15<00:06,  4.96it/s]
#
#
#
#
#
#
#
#
#  92%|█████████▏| 364/394 [01:16<00:06,  4.96it/s]
#
#
#
#
#
#
#
#
#  93%|█████████▎| 365/394 [01:16<00:05,  4.94it/s]
#
#
#
#
#
#
#
#
#  93%|█████████▎| 366/394 [01:16<00:05,  4.97it/s]
#
#
#
#
#
#
#
#
#  93%|█████████▎| 367/394 [01:16<00:05,  4.97it/s]
#
#
#
#
#
#
#
#
#  93%|█████████▎| 368/394 [01:16<00:05,  4.98it/s]
#
#
#
#
#
#
#
#
#  94%|█████████▎| 369/394 [01:17<00:05,  4.97it/s]
#
#
#
#
#
#
#
#
#  94%|█████████▍| 370/394 [01:17<00:04,  4.98it/s]
#
#
#
#
#
#
#
#
#  94%|█████████▍| 371/394 [01:17<00:04,  5.00it/s]
#
#
#
#
#
#
#
#
#  94%|█████████▍| 372/394 [01:17<00:04,  5.00it/s]
#
#
#
#
#
#
#
#
#  95%|█████████▍| 373/394 [01:17<00:04,  4.99it/s]
#
#
#
#
#
#
#
#
#  95%|█████████▍| 374/394 [01:18<00:04,  4.96it/s]
#
#
#
#
#
#
#
#
#  95%|█████████▌| 375/394 [01:18<00:03,  4.95it/s]
#
#
#
#
#
#
#
#
#  95%|█████████▌| 376/394 [01:18<00:03,  4.97it/s]
#
#
#
#
#
#
#
#
#  96%|█████████▌| 377/394 [01:18<00:03,  4.96it/s]
#
#
#
#
#
#
#
#
#  96%|█████████▌| 378/394 [01:18<00:03,  4.96it/s]
#
#
#
#
#
#
#
#
#  96%|█████████▌| 379/394 [01:19<00:03,  4.96it/s]
#
#
#
#
#
#
#
#
#  96%|█████████▋| 380/394 [01:19<00:02,  4.96it/s]
#  97%|█████████▋| 381/394 [01:19<00:02,  4.99it/s]
#
#
#
#
#
#
#
#
#  97%|█████████▋| 382/394 [01:19<00:02,  5.00it/s]
#
#
#
#
#
#
#
#
#  97%|█████████▋| 383/394 [01:19<00:02,  4.97it/s]
#
#
#
#
#
#
#
#
#  97%|█████████▋| 384/394 [01:20<00:02,  4.94it/s]
#
#
#
#
#
#
#
#
#  98%|█████████▊| 385/394 [01:20<00:01,  4.94it/s]
#
#
#
#
#
#
#
#
#  98%|█████████▊| 386/394 [01:20<00:01,  4.93it/s]
#
#
#
#
#
#
#
#
#  98%|█████████▊| 387/394 [01:20<00:01,  4.94it/s]
#
#
#
#
#
#
#
#
# 100%|██████████| 394/394 [01:20<00:00,  4.88it/s]

# %%
year_weekly = pd.concat(rows)
year_weekly.tail()
# Out:
#      INSP_DATE2          c          d Year_Week
# 2703 2019-05-27 2019-05-26 2019-06-01   2019_22
# 2704 2019-05-28 2019-05-26 2019-06-01   2019_22
# 2705 2019-05-29 2019-05-26 2019-06-01   2019_22
# 2706 2019-05-30 2019-05-26 2019-06-01   2019_22
# 2707 2019-05-31 2019-05-26 2019-06-01   2019_22

# %%
# unique week
week_total = year_weekly.Year_Week.unique()

# %%
date_week = collections.defaultdict()
for i in range(year_weekly.shape[0]):
    date_key = year_weekly.INSP_DATE2[i]
    week_val = year_weekly.Year_Week[i]
    date_week[date_key] = week_val

# %%
# find missing week
def intersection(lst1, lst2): 
    return list(set(lst1) & set(lst2))

# %%
b = set(n_week_ks)
a = set(n_week_2012_2019)

c = {element for element in a if element not in b}
print(c)
# Out:
# {'2013-06', '2017-53'}

# %% [markdown]
# # Pre-processing Weather data

# %%
import pandas as pd
from os import listdir
from os.path import isfile, join
import numpy as np

# %%
mypath = './data/tw_weekly_weather/'
listdir(mypath)
# Out:
# ['Miaoli',
#  'Tainan',
#  'Penghu',
#  'Chiayi',
#  'Taichung',
#  'Hsinchu',
#  'Nantou',
#  'Pingtung',
#  'Changhua',
#  'Lienchang',
#  'Taoyuan',
#  'Taitung',
#  'Kinmen',
#  'New Taipei',
#  'Yunlin',
#  'Hualien',
#  'Keelung',
#  'Yilan',
#  'Kaohsiung',
#  'Taipei']

# %%
folders = [mypath + folder + '/' for folder in listdir(mypath)]
print(folders)
# Out:
# ['./tw_weekly_weather/Miaoli/', './tw_weekly_weather/Tainan/', './tw_weekly_weather/Penghu/', './tw_weekly_weather/Chiayi/', './tw_weekly_weather/Taichung/', './tw_weekly_weather/Hsinchu/', './tw_weekly_weather/Nantou/', './tw_weekly_weather/Pingtung/', './tw_weekly_weather/Changhua/', './tw_weekly_weather/Lienchang/', './tw_weekly_weather/Taoyuan/', './tw_weekly_weather/Taitung/', './tw_weekly_weather/Kinmen/', './tw_weekly_weather/New Taipei/', './tw_weekly_weather/Yunlin/', './tw_weekly_weather/Hualien/', './tw_weekly_weather/Keelung/', './tw_weekly_weather/Yilan/', './tw_weekly_weather/Kaohsiung/', './tw_weekly_weather/Taipei/']

# %%
from collections import defaultdict

folders_files = defaultdict(list)
for folder in folders:
    folders_files[folder] = listdir(folder)

# %% [markdown]
# ### Get final preprocessed for Weather

# %%
all_county_weather = collections.defaultdict()

print('\n Count missing weeks of weather \n')

for key_county, value_files in folders_files.items():
    
    cty_name = key_county.split('/')[-2]
    if cty_name == 'Kinmen' or cty_name == 'Lienchang':
        continue
    #print(cty_name, '\n')
    county = add_date_to_county(key_county, cut_year = 2012)
    # count nan

        
    # fill nan, need to change
    cty = fill_nan_dummy(county)
    

    cty1 = weather_convert_date_to_yyyy_ww(cty, new_date_week)
    
    # groupby week
    cty2 = groupby_yyyy_ww(cty1, col = 'Year_Week')
    
    # count missing data
    selected_words = [float('NaN')]
    print('\n', '*' * 20, 'Cty name = ', cty_name, '*'*20)
    for c in cty2:
        print('\n', cty2.loc[cty2[c].isin(selected_words),c].value_counts())
    
    all_county_weather[cty_name] = cty2
# Out:
#  ******************** Cty name =  Changhua ********************
#
#  Series([], Name: Year_Week, dtype: int64)
#
#  Series([], Name: Temperature, dtype: int64)
#
#  Series([], Name: T Max, dtype: int64)
#
#  Series([], Name: T Min, dtype: int64)
#
#  Series([], Name: RH, dtype: int64)
#
#  Series([], Name: Precp, dtype: int64)
#
#  Series([], Name: Year, dtype: int64)
#
#  ******************** Cty name =  Taitung ********************
#
#  Series([], Name: Year_Week, dtype: int64)
#
#  Series([], Name: Temperature, dtype: int64)
#
#  Series([], Name: T Max, dtype: int64)
#
#  Series([], Name: T Min, dtype: int64)
#
#  Series([], Name: RH, dtype: int64)
#
#  Series([], Name: Precp, dtype: int64)
#
#  Series([], Name: Year, dtype: int64)
#
#  ******************** Cty name =  Nantou ********************
#
#  Series([], Name: Year_Week, dtype: int64)
#
#  Series([], Name: Temperature, dtype: int64)
#
#  Series([], Name: T Max, dtype: int64)
#
#  Series([], Name: T Min, dtype: int64)
#
#  Series([], Name: RH, dtype: int64)
#
#  Series([], Name: Precp, dtype: int64)
#
#  Series([], Name: Year, dtype: int64)
#
#  ******************** Cty name =  Taipei ********************
#
#  Series([], Name: Year_Week, dtype: int64)
#
#  Series([], Name: Temperature, dtype: int64)
#
#  Series([], Name: T Max, dtype: int64)
#
#  Series([], Name: T Min, dtype: int64)
#
#  Series([], Name: RH, dtype: int64)
#
#  Series([], Name: Precp, dtype: int64)
#
#  Series([], Name: Year, dtype: int64)
#
#  ******************** Cty name =  Hualien ********************
#
#  Series([], Name: Year_Week, dtype: int64)
#
#  Series([], Name: Temperature, dtype: int64)
#
#  Series([], Name: T Max, dtype: int64)
#
#  Series([], Name: T Min, dtype: int64)
#
#  Series([], Name: RH, dtype: int64)
#
#  Series([], Name: Precp, dtype: int64)
#
#  Series([], Name: Year, dtype: int64)
#
#  ******************** Cty name =  Kaohsiung ********************
#
#  Series([], Name: Year_Week, dtype: int64)
#
#  Series([], Name: Temperature, dtype: int64)
#
#  Series([], Name: T Max, dtype: int64)
#
#  Series([], Name: T Min, dtype: int64)
#
#  Series([], Name: RH, dtype: int64)
#
#  Series([], Name: Precp, dtype: int64)
#
#  Series([], Name: Year, dtype: int64)
#
#  ******************** Cty name =  Taichung ********************
#
#  Series([], Name: Year_Week, dtype: int64)
#
#  Series([], Name: Temperature, dtype: int64)
#
#  Series([], Name: T Max, dtype: int64)
#
#  Series([], Name: T Min, dtype: int64)
#
#  Series([], Name: RH, dtype: int64)
#
#  Series([], Name: Precp, dtype: int64)
#
#  Series([], Name: Year, dtype: int64)
#
#  ******************** Cty name =  Taoyuan ********************
#
#  Series([], Name: Year_Week, dtype: int64)
#
#  Series([], Name: Temperature, dtype: int64)
#
#  Series([], Name: T Max, dtype: int64)
#
#  Series([], Name: T Min, dtype: int64)
#
#  Series([], Name: RH, dtype: int64)
#
#  Series([], Name: Precp, dtype: int64)
#
#  Series([], Name: Year, dtype: int64)
#
#  ******************** Cty name =  Yunlin ********************
#
#  Series([], Name: Year_Week, dtype: int64)
#
#  Series([], Name: Temperature, dtype: int64)
#
#  Series([], Name: T Max, dtype: int64)
#
#  Series([], Name: T Min, dtype: int64)
#
#  Series([], Name: RH, dtype: int64)
#
#  Series([], Name: Precp, dtype: int64)
#
#  Series([], Name: Year, dtype: int64)
#
#  ******************** Cty name =  Keelung ********************
#
#  Series([], Name: Year_Week, dtype: int64)
#
#  Series([], Name: Temperature, dtype: int64)
#
#  Series([], Name: T Max, dtype: int64)
#
#  Series([], Name: T Min, dtype: int64)
#
#  Series([], Name: RH, dtype: int64)
#
#  Series([], Name: Precp, dtype: int64)
#
#  Series([], Name: Year, dtype: int64)
#
#  ******************** Cty name =  Pingtung ********************
#
#  Series([], Name: Year_Week, dtype: int64)
#
#  Series([], Name: Temperature, dtype: int64)
#
#  Series([], Name: T Max, dtype: int64)
#
#  Series([], Name: T Min, dtype: int64)
#
#  Series([], Name: RH, dtype: int64)
#
#  Series([], Name: Precp, dtype: int64)
#
#  Series([], Name: Year, dtype: int64)
#
#  ******************** Cty name =  Tainan ********************
#
#  Series([], Name: Year_Week, dtype: int64)
#
#  Series([], Name: Temperature, dtype: int64)
#
#  Series([], Name: T Max, dtype: int64)
#
#  Series([], Name: T Min, dtype: int64)
#
#  Series([], Name: RH, dtype: int64)
#
#  Series([], Name: Precp, dtype: int64)
#
#  Series([], Name: Year, dtype: int64)
#
#  ******************** Cty name =  Hsinchu ********************
#
#  Series([], Name: Year_Week, dtype: int64)
#
#  Series([], Name: Temperature, dtype: int64)
#
#  Series([], Name: T Max, dtype: int64)
#
#  Series([], Name: T Min, dtype: int64)
#
#  Series([], Name: RH, dtype: int64)
#
#  Series([], Name: Precp, dtype: int64)
#
#  Series([], Name: Year, dtype: int64)
#
#  ******************** Cty name =  Chiayi ********************
#
#  Series([], Name: Year_Week, dtype: int64)
#
#  Series([], Name: Temperature, dtype: int64)
#
#  Series([], Name: T Max, dtype: int64)
#
#  Series([], Name: T Min, dtype: int64)
#
#  Series([], Name: RH, dtype: int64)
#
#  Series([], Name: Precp, dtype: int64)
#
#  Series([], Name: Year, dtype: int64)
#
#  ******************** Cty name =  Miaoli ********************
#
#  Series([], Name: Year_Week, dtype: int64)
#
#  Series([], Name: Temperature, dtype: int64)
#
#  Series([], Name: T Max, dtype: int64)
#
#  Series([], Name: T Min, dtype: int64)
#
#  Series([], Name: RH, dtype: int64)
#
#  Series([], Name: Precp, dtype: int64)
#
#  Series([], Name: Year, dtype: int64)
#
#  ******************** Cty name =  Yilan ********************
#
#  Series([], Name: Year_Week, dtype: int64)
#
#  Series([], Name: Temperature, dtype: int64)
#
#  Series([], Name: T Max, dtype: int64)
#
#  Series([], Name: T Min, dtype: int64)
#
#  Series([], Name: RH, dtype: int64)
#
#  Series([], Name: Precp, dtype: int64)
#
#  Series([], Name: Year, dtype: int64)
#
#  ******************** Cty name =  Penghu ********************
#
#  Series([], Name: Year_Week, dtype: int64)
#
#  Series([], Name: Temperature, dtype: int64)
#
#  Series([], Name: T Max, dtype: int64)
#
#  Series([], Name: T Min, dtype: int64)
#
#  Series([], Name: RH, dtype: int64)
#
#  Series([], Name: Precp, dtype: int64)
#
#  Series([], Name: Year, dtype: int64)
#
#  ******************** Cty name =  New Taipei ********************
#
#  Series([], Name: Year_Week, dtype: int64)
#
#  Series([], Name: Temperature, dtype: int64)
#
#  Series([], Name: T Max, dtype: int64)
#
#  Series([], Name: T Min, dtype: int64)
#
#  Series([], Name: RH, dtype: int64)
#
#  Series([], Name: Precp, dtype: int64)
#
#  Series([], Name: Year, dtype: int64)

# %%
# example: Miaoli weather
all_county_weather['Miaoli'].tail()
# Out:
#     Year_Week  Temperature      T Max      T Min         RH      Precp    Year
# 382   2019_18    22.971429  27.257143  20.028571  79.285714  12.214286  2019.0
# 383   2019_19    21.614286  24.914286  19.085714  85.285714   4.428571  2019.0
# 384   2019_20    26.757143  29.942857  23.742857  82.428571  10.785714  2019.0
# 385   2019_21    25.128571  28.485714  22.442857  78.000000   7.928571  2019.0
# 386   2019_22    25.050000  28.300000  22.400000  82.000000  13.166667  2019.0

# %%
# example: Miaoli BI, CI, HI
data_fin2[cty_en_cn['Miaoli']].tail()
# Out:
#      YYYY_WW        BI         CI        HI County
# 382  2019_18  2.918082  11.949789  2.625244    苗栗縣
# 383  2019_19  2.918082  11.949789  2.625244    苗栗縣
# 384  2019_20  2.918082  11.949789  2.625244    苗栗縣
# 385  2019_21  2.918082  11.949789  2.625244    苗栗縣
# 386  2019_22  2.918082  11.949789  2.625244    苗栗縣

# %% [markdown]
# ### Compile Weather + BI data

# %%
full_data = []
for cty_cn, cty_en in cty_cn_en.items():
    bi = data_fin2[cty_cn]
    te = all_county_weather[cty_en]
    tmp = [bi, te]
    cty_bi_te = pd.concat(tmp, axis = 1) # concat column-by-column & keep old column names
    full_data.append(cty_bi_te)

# %%
full_data2 = pd.concat(full_data, axis = 0, ignore_index = True) # concat row-by-row & auto generate new index

# %%
full_data2.shape
# Out:
# (6966, 12)

# %% [markdown]
# # FINAL PREPROCESSED DATA (FULL 18 COUNTY + WEATHER + BI, CI, HI)

# %%
full_data2.head()
# Out:
#    YYYY_WW        BI        CI        HI County Year_Week  Temperature  \
# 0  2012_01  0.826830  3.773274  0.749364    新竹縣   2012_01    14.028571
# 1  2012_02  0.822733  5.657047  0.692000    新竹縣   2012_02    16.942857
# 2  2012_03  0.093333  0.793611  0.093333    新竹縣   2012_03    16.642857
# 3  2012_04  0.111562  0.694438  0.111562    新竹縣   2012_04    13.500000
# 4  2012_05  0.865533  4.806850  0.833483    新竹縣   2012_05    14.928571
#
#        T Max      T Min         RH     Precp    Year
# 0  16.985714  12.028571  85.000000  7.500000  2012.0
# 1  19.342857  15.314286  85.714286  2.081177  2012.0
# 2  19.914286  14.742857  88.142857  5.342857  2012.0
# 3  16.028571  11.614286  89.857143  7.233445  2012.0
# 4  17.485714  13.214286  88.428571  2.024034  2012.0

# %%
write_data = full_data2[['County', 'YYYY_WW', 'BI', 'CI', 'HI', 'Temperature', 'T Max', 'T Min', 'RH', 'Precp']]
write_data.head()
# Out:
#   County  YYYY_WW        BI        CI        HI  Temperature      T Max  \
# 0    新竹縣  2012_01  0.826830  3.773274  0.749364    14.028571  16.985714
# 1    新竹縣  2012_02  0.822733  5.657047  0.692000    16.942857  19.342857
# 2    新竹縣  2012_03  0.093333  0.793611  0.093333    16.642857  19.914286
# 3    新竹縣  2012_04  0.111562  0.694438  0.111562    13.500000  16.028571
# 4    新竹縣  2012_05  0.865533  4.806850  0.833483    14.928571  17.485714
#
#        T Min         RH     Precp
# 0  12.028571  85.000000  7.500000
# 1  15.314286  85.714286  2.081177
# 2  14.742857  88.142857  5.342857
# 3  11.614286  89.857143  7.233445
# 4  13.214286  88.428571  2.024034

# %%
# add County column in English
tmp = list(write_data.County)
cty_en = []
for cty_cn in tmp:
    cty_en.append(cty_cn_en[cty_cn])
    
tmp2 = pd.Series(cty_en)
write_data['County'] = tmp2
write_data.tail()
# Out:
# /home/basic/tensorflow/tensorflow_pkg/tf_1.12_cuda10.0/lib/python3.5/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
#        County  YYYY_WW        BI        CI        HI  Temperature      T Max  \
# 6961  Hualien  2019_18  0.474699  2.853305  0.395142    24.071429  27.371429
# 6962  Hualien  2019_19  0.474699  2.853305  0.395142    22.957143  25.942857
# 6963  Hualien  2019_20  0.474699  2.853305  0.395142    26.728571  30.000000
# 6964  Hualien  2019_21  0.474699  2.853305  0.395142    24.171429  27.642857
# 6965  Hualien  2019_22  0.474699  2.853305  0.395142    25.233333  28.850000
#
#           T Min         RH      Precp
# 6961  21.385714  76.857143   6.722184
# 6962  20.714286  81.285714   4.000000
# 6963  24.285714  80.571429   8.507898
# 6964  21.885714  78.714286  12.285714
# 6965  22.766667  80.833333   1.416667

# %%
write_data.to_csv('fullhouse.csv')

# %% [markdown]
# #### Utils

# %%
def add_date_to_county(folder_path, cut_year = 2012):
    county = [] # one county
    
    tmp = sorted(list(folders_files[folder_path]))
    for file in tmp:
        file_path = folder_path + file
        tmp_data = pd.read_csv(file_path)
        
        _, yyyy, mm = file.split('.')[0].split('-')
        yyyy_mm = yyyy + '-' + mm
        
        tmp2 = list(tmp_data.ObsTime)
        tmp3 = []
        for day in tmp2:
            if day < 10:
                day_str = '0'+ str(day)
            else:
                day_str = str(day)
            yyyy_mm_dd = yyyy_mm + '-' + day_str
            
            tmp3.append(yyyy_mm_dd)
            
        tmp_data['Date'] = tmp3
        
        use_cols = ['Temperature', 'T Max', 'T Min', 'RH', 'Precp', 'Date']
        
        tmp_data2 = tmp_data[use_cols]
        
        county.append(tmp_data2)
        
        county_df = pd.concat(county)
        
        # select year
        county_df['Year'] = pd.to_datetime(county_df['Date']).dt.year

        county_df = county_df[county_df['Year'] >= cut_year]
        
    return county_df

# %%
def fill_nan_dummy(county_df):
        

        
    county_df = county_df.replace(to_replace='T', value=float('NaN'))
    county_df = county_df.replace(to_replace='X', value=float('NaN'))
    county_df = county_df.replace(to_replace='/', value=float('NaN'))
    county_df = county_df.replace(to_replace='...', value=float('NaN'))
    #county_df = county_df.replace(to_replace= 'inf', value=float('NaN'))

    county_df['Temperature'] = county_df['Temperature'].astype(float)
    county_df['T Max'] = county_df['T Max'].astype(float)
    county_df['T Min'] = county_df['T Min'].astype(float)
    county_df['Precp'] = county_df['Precp'].astype(float)
    county_df['RH'] = county_df['RH'].astype(float)

    
    return county_df


def fill_nan(county_df):
        

        
    county_df = county_df.replace(to_replace='T', value=float('NaN'))
    county_df = county_df.replace(to_replace='X', value=float('NaN'))
    county_df = county_df.replace(to_replace='/', value=float('NaN'))
    county_df = county_df.replace(to_replace='...', value=float('NaN'))
    #county_df = county_df.replace(to_replace= 'inf', value=float('NaN'))

    county_df['Temperature'] = county_df['Temperature'].astype(float)
    county_df['T Max'] = county_df['T Max'].astype(float)
    county_df['T Min'] = county_df['T Min'].astype(float)
    county_df['Precp'] = county_df['Precp'].astype(float)
    county_df['RH'] = county_df['RH'].astype(float)

    #data_x2 = pd.DataFrame(data_x, columns = weather_cols, dtype = float)

    #df['feature_count'].fillna(df['client_name'].map(s), inplace=True)
    county_df['Temperature'] = county_df['Temperature'].fillna(county_df['Temperature'].mean())
    
    county_df['T Max'] = county_df['T Max'].fillna(county_df['T Max'].mean())
    county_df['T Min'] = county_df['T Min'].fillna(county_df['T Min'].mean())
    county_df['Precp'] = county_df['Precp'].fillna(county_df['Precp'].mean()) 
    county_df['RH'] = county_df['RH'].fillna(county_df['RH'].mean()) 
    
    return county_df

# %%
# date_week dict, ex: 2019-5-31: 2019_22
new_date_week = {}
for k, v in date_week.items():
    yyyy_mm_dd, _ = str((k)).split(' ')
    new_date_week[yyyy_mm_dd] = v

# %%
def weather_convert_date_to_yyyy_ww(data_frame, yyyy_ww_dict):
    '''
    Input: data_frame
    Output: data_frame added yyyy_ww column
    '''
    yyww = []
    tmp = data_frame.Date
    date_key = list(tmp)
    
    for i in range(data_frame.shape[0]):
        
        k = date_key[i]
        try:
            yw = yyyy_ww_dict[k]
            #print(k, '-'*10, yw)
            yyww.append(yw)
        except: KeyError
            
        
    Year_Week = pd.Series(yyww)

    
    data_frame = data_frame.reset_index(drop = True)
    
    data_frame['Year_Week'] = Year_Week

    return data_frame

# %%
def weather_gen_full_time_table(data_frame, week_total, county = ''):
    '''
    Input: 
        data_frame: data with missing weeks of years
        week_total: total number of yyyy_ww 
    Output: 
        full_table: data_frame fulfilled missed yyyy_ww based on week_total
    
    '''
    
    full_table = []
    j = 0
    for i in tqdm(range(len(week_total))):
        #print(i)

        yw_ref = week_total[i]
        
        try:
            yw_cty = sorted(data_frame.Year_Week)[j]
        except: IndexError
            
        #print(yw_cty)
        #print(j, yw_ref, yw_cty)

        if yw_ref == yw_cty:
            temp = data_frame['Temperature'][j]
            tmax = data_frame['T Max'][j]
            tmin = data_frame['T Min'][j]
            rh = data_frame['RH'][j]
            recp = data_frame['Precp'][j]

            full_table.append([yw_ref, temp, tmax, tmin, rh, recp])
            j += 1
            continue

        else:
            full_table.append([yw_ref, float('nan'), float('nan'), float('nan')])
            continue
            
    full_table = pd.DataFrame(full_table, columns = ['YYYY_WW', 'Temperature', 'T Max', 'T Min', 'RH', 'Precp'])
    full_table['County'] = county
    
    return full_table

# %%
# TW county in Chinese English dict
cty_chinese = ['台北市', '高雄市', '台中市', '宜蘭縣', '台南市', 
               '新北市', '彰化縣', '花蓮縣', '雲林縣', 
               '新竹縣', '嘉義縣', '桃園市', '澎湖縣', '南投縣', 
               '屏東縣', '台東縣', '基隆市', '苗栗縣'] # '連江縣', '金門縣'

cty_english = ['Taipei', 'Kaohsiung', 'Taichung', 'Yilan',  'Tainan',
               'New Taipei', 'Changhua', 'Hualien', 'Yunlin',
               'Hsinchu',  'Chiayi',  'Taoyuan',  'Penghu',  'Nantou',
               'Pingtung', 'Taitung',  'Keelung', 'Miaoli']

cty_cn_en = collections.defaultdict()
cty_en_cn = collections.defaultdict()

# create 2 dict
for cn, en in zip(cty_chinese, cty_english):
    cty_cn_en[cn] = en
    cty_en_cn[en] = cn

# %% [markdown]
# ##### END
